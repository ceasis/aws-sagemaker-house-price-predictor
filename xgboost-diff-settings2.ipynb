# %% [markdown]
# # UPDATE DEPENDENCIES

# %%
# IRIS DATA SET
# https://archive.ics.uci.edu/dataset/53/iris

# XG BOOST DOCS
# https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html

# %%
# !pip install --upgrade xgboost
# !pip install --upgrade scipy
# !pip install --upgrade scikit-learn
# !pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: xgboost in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from xgboost) (2.1.2)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from xgboost) (1.14.1)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scipy) (2.1.2)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (2.1.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# # PREPARE DATA

# %%
import urllib.request
urllib.request.urlretrieve('https://archive.ics.uci.edu/static/public/53/iris.zip','data.zip')
# Out:
# ('data.zip', <http.client.HTTPMessage at 0x7f4dfaf3e9b0>)

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from io import StringIO
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import xgboost as xgb  # Import xgboost

data = pd.read_csv('iris-data/iris.data', header=None)

# convert to numerical values
data[4] = data[4].replace('Iris-setosa',0)
data[4] = data[4].replace('Iris-virginica',1)
data[4] = data[4].replace('Iris-versicolor',2)
data = data[[4,0,1,2,3]]
print('DATA', data)

new_values = [
    [5.0, 3.6, 1.4, 0.2, 2],  # Iris-setosa
    [6.0, 2.9, 4.5, 1.5, 2],  # Iris-versicolor
    [6.5, 3.2, 5.1, 2.0, 1],  # Iris-virginica
    [5.9, 3.0, 5.1, 1.8, 1]  # Iris-virginica
]

new_rows = pd.DataFrame(new_values)
#data = pd.concat([data, new_rows], ignore_index=True)

data = data.sample(frac=1).reset_index(drop=True)

# Split features (X) and target (y), assuming the first column (0) is the label
X_features = data.drop(4, axis=1)  # Features (all columns except column 0)
y_labels = data[4]  # Target labels (column 0)

print('X', X_features)
print('y', y_labels)

X_features.to_csv('iris-data/X-features-data.csv', index=False, header=False)
y_labels.to_csv('iris-data/y-labels-data.csv', index=False, header=False)

X_data = pd.read_csv('iris-data/X-features-data.csv', header=None)
y_data = pd.read_csv('iris-data/y-labels-data.csv', header=None)

print('X-data', X_data)
print('y-data', y_data)

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=42)

print('X_train', X_train)
print('y_train', y_train)

print('X_test', X_test)
print('y_test', y_test)

print('TOTAL X_train: ',len(X_train))
print('TOTAL y_train: ', len(y_train))

print('TOTAL X_test: ', len(X_test))
print('TOTAL y_test: ', len(y_test))


num_rounds = [1,5,9,20]
accuracies = []
rounds = []
max_accuracy = 0

for x in range(1,500):
    max_depth = random.randint(1, 1)  # Random depth between 1 and 10
    learning_rate = random.uniform(0.01, 0.075)  # Random learning rate between 0.01 and 0.3
    n_estimators = random.randint(1, 1)  # Random number of estimators (boosting rounds)
    min_child_weight = random.randint(1, 1)  # Random min_child_weight between 1 and 10
    subsample = random.uniform(0.5, 0.643)  # Random subsample ratio between 0.5 and 1.0
    colsample_bytree = random.uniform(0.5, 1.0)  # Random colsample_bytree between 0.5 and 1.0
    gamma = random.uniform(0, 5)  # Random gamma between 0 and 5
    reg_lambda = random.uniform(0, 5)  # Random L2 regularization term
    reg_alpha = random.uniform(0, 3.4489)  # Random L1 regularization term
    
    # Configure and train the XGBoost model with the current num_round
    xgb_model = xgb.XGBClassifier(
        max_depth=max_depth,
        learning_rate=learning_rate,
        n_estimators=n_estimators,
        min_child_weight=min_child_weight,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        gamma=gamma,
        reg_lambda=reg_lambda,
        reg_alpha=reg_alpha,
        objective='multi:softmax',  # For multiclass classification
        num_class=3  # Assuming 3 classes
    )
    
    xgb_model.fit(X_train,y_train)

    y_pred = None
    y_pred = xgb_model.predict(X_test)
    
    print("TEST:", y_test.values.flatten())
    print("PRED:", y_pred)
    
    # Calculate accuracy for the current num_round
    accuracy = accuracy_score(y_test, y_pred)
    rounds.append(x)
    accuracies.append(accuracy)
    
    if(accuracy >= max_accuracy):
        max_accuracy = accuracy
        print(xgb_model.get_params())
        print(f"num_round: {num_round}, Accuracy: {accuracy:.3f}")

# Plot the accuracies
plt.figure(figsize=(10, 6))
plt.plot(rounds, accuracies, marker='o')
plt.title('Effect of num_round on Model Accuracy')
plt.xlabel('num_round')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_8929/2265072760.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[4] = data[4].replace('Iris-versicolor',2)
# DATA      4    0    1    2    3
# 0    0  5.1  3.5  1.4  0.2
# 1    0  4.9  3.0  1.4  0.2
# 2    0  4.7  3.2  1.3  0.2
# 3    0  4.6  3.1  1.5  0.2
# 4    0  5.0  3.6  1.4  0.2
# ..  ..  ...  ...  ...  ...
# 145  1  6.7  3.0  5.2  2.3
# 146  1  6.3  2.5  5.0  1.9
# 147  1  6.5  3.0  5.2  2.0
# 148  1  6.2  3.4  5.4  2.3
# 149  1  5.9  3.0  5.1  1.8
#
# [150 rows x 5 columns]
# X        0    1    2    3
# 0    5.6  2.9  3.6  1.3
# 1    5.8  2.7  4.1  1.0
# 2    6.5  3.0  5.5  1.8
# 3    5.5  3.5  1.3  0.2
# 4    6.7  3.3  5.7  2.1
# ..   ...  ...  ...  ...
# 145  5.5  2.6  4.4  1.2
# 146  6.7  2.5  5.8  1.8
# 147  5.6  3.0  4.5  1.5
# 148  7.7  2.6  6.9  2.3
# 149  6.3  2.5  4.9  1.5
#
# [150 rows x 4 columns]
# y 0      2
# 1      2
# 2      1
# 3      0
# 4      1
#       ..
# 145    2
# 146    1
# 147    2
# 148    1
# 149    2
# Name: 4, Length: 150, dtype: int64
# X-data        0    1    2    3
# 0    5.6  2.9  3.6  1.3
# 1    5.8  2.7  4.1  1.0
# 2    6.5  3.0  5.5  1.8
# 3    5.5  3.5  1.3  0.2
# 4    6.7  3.3  5.7  2.1
# ..   ...  ...  ...  ...
# 145  5.5  2.6  4.4  1.2
# 146  6.7  2.5  5.8  1.8
# 147  5.6  3.0  4.5  1.5
# 148  7.7  2.6  6.9  2.3
# 149  6.3  2.5  4.9  1.5
#
# [150 rows x 4 columns]
# y-data      0
# 0    2
# 1    2
# 2    1
# 3    0
# 4    1
# ..  ..
# 145  2
# 146  1
# 147  2
# 148  1
# 149  2
#
# [150 rows x 1 columns]
# X_train        0    1    2    3
# 81   5.8  2.7  5.1  1.9
# 133  6.1  2.6  5.6  1.4
# 137  5.5  2.4  3.7  1.0
# 75   6.3  2.7  4.9  1.8
# 109  6.2  2.9  4.3  1.3
# ..   ...  ...  ...  ...
# 71   6.9  3.2  5.7  2.3
# 106  4.9  3.1  1.5  0.1
# 14   5.9  3.2  4.8  1.8
# 92   5.7  2.8  4.1  1.3
# 102  6.2  2.2  4.5  1.5
#
# [105 rows x 4 columns]
# y_train      0
# 81   1
# 133  1
# 137  2
# 75   1
# 109  2
# ..  ..
# 71   1
# 106  0
# 14   2
# 92   2
# 102  2
#
# [105 rows x 1 columns]
# X_test        0    1    2    3
# 73   6.7  3.1  4.7  1.5
# 18   6.7  3.1  5.6  2.4
# 118  5.1  3.8  1.5  0.3
# 78   5.2  4.1  1.5  0.1
# 76   6.4  3.1  5.5  1.8
# 31   5.7  2.5  5.0  2.0
# 64   5.5  2.3  4.0  1.3
# 141  6.5  3.0  5.8  2.2
# 68   5.5  2.4  3.8  1.1
# 82   7.6  3.0  6.6  2.1
# 110  4.6  3.1  1.5  0.2
# 12   7.2  3.2  6.0  1.8
# 36   6.1  2.9  4.7  1.4
# 9    4.8  3.4  1.6  0.2
# 19   5.0  3.4  1.5  0.2
# 56   4.9  2.5  4.5  1.7
# 104  6.4  2.7  5.3  1.9
# 69   6.4  2.9  4.3  1.3
# 55   6.7  3.0  5.0  1.7
# 132  6.3  2.8  5.1  1.5
# 29   6.1  2.8  4.0  1.3
# 127  5.8  2.7  5.1  1.9
# 26   6.8  3.0  5.5  2.1
# 128  5.1  3.5  1.4  0.2
# 131  5.8  2.6  4.0  1.2
# 145  5.5  2.6  4.4  1.2
# 108  6.3  3.3  4.7  1.6
# 143  5.4  3.0  4.5  1.5
# 45   6.0  2.9  4.5  1.5
# 30   6.5  3.0  5.2  2.0
# 22   5.1  3.8  1.9  0.4
# 15   5.6  2.7  4.2  1.3
# 65   7.7  2.8  6.7  2.0
# 11   5.4  3.9  1.7  0.4
# 42   4.8  3.0  1.4  0.3
# 146  6.7  2.5  5.8  1.8
# 51   5.9  3.0  5.1  1.8
# 27   5.4  3.4  1.5  0.4
# 4    6.7  3.3  5.7  2.1
# 32   6.8  3.2  5.9  2.3
# 142  5.2  3.5  1.5  0.2
# 85   6.6  3.0  4.4  1.4
# 86   4.4  2.9  1.4  0.2
# 16   4.9  3.1  1.5  0.1
# 10   4.4  3.2  1.3  0.2
# y_test      0
# 73   2
# 18   1
# 118  0
# 78   0
# 76   1
# 31   1
# 64   2
# 141  1
# 68   2
# 82   1
# 110  0
# 12   1
# 36   2
# 9    0
# 19   0
# 56   1
# 104  1
# 69   2
# 55   2
# 132  1
# 29   2
# 127  1
# 26   1
# 128  0
# 131  2
# 145  2
# 108  2
# 143  2
# 45   2
# 30   1
# 22   0
# 15   2
# 65   1
# 11   0
# 42   0
# 146  1
# 51   1
# 27   0
# 4    1
# 32   1
# 142  0
# 85   2
# 86   0
# 16   0
# 10   0
# TOTAL X_train:  105
# TOTAL y_train:  105
# TOTAL X_test:  45
# TOTAL y_test:  45
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6277217069199323, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 2.71415776378884, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.02823058815193303, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.247410487827367, 'reg_lambda': 0.6583185001234027, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5929281944184882, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9410983866648277, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.67161902379071, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.052217941743154556, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 2.7262671654178754, 'reg_lambda': 4.047952060795442, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5798510383145952, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8169043232663987, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 3.066873214756718, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.045630774901631276, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.4311954544272389, 'reg_lambda': 0.7639150674368295, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5882363890809658, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9668198046331002, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.678893260850913, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.027940001245627996, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.8858090446696398, 'reg_lambda': 3.43590450182436, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5870549541945214, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9035421546166427, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 3.8175106909132905, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.0676795046421454, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.3069640851548668, 'reg_lambda': 4.248056580765727, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5438391331481612, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9062272229281312, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.3932885582139864, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.0342229842831449, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 2.86059391629641, 'reg_lambda': 0.09325429518325268, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6087230907022222, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.7610218941074208, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.2632506919727575, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.017571143553631145, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.806917043618032, 'reg_lambda': 0.04788158971187784, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5002619782103988, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9164571688887755, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.5740392657261677, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.032047193580070764, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 3.310255579351968, 'reg_lambda': 2.6611911333532805, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5408611895183721, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9218369964120245, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.8911426390355615, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.030709690985064153, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.3745152333067452, 'reg_lambda': 0.5535328173018883, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6027410362102983, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8670153893591747, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.3688410419193542, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.020142558503967553, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 2.0118997439408397, 'reg_lambda': 3.1994786245229436, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5976435964094702, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.997779770234563, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 2.968617491694332, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.018308197103967208, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.14782028633550767, 'reg_lambda': 2.6455986449183526, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6245252072209398, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6265897681910965, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 2.51702049993183, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.01673706803221147, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.2640729264949694, 'reg_lambda': 1.0479396054535584, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5147218829805603, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8436174126523809, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.163316990771124, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.029455889222254568, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 3.300708307956753, 'reg_lambda': 4.367889205587126, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5492245137562615, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.974048280497835, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.08695056612360863, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.019107370006112245, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.2821392356550931, 'reg_lambda': 4.385292417805468, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.638283827899115, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9768893147884203, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.698733417003897, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05184953787963517, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 2.790545735028016, 'reg_lambda': 2.0686826306951938, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6087141006332775, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8202215728574194, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.17356875485420364, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.040015441946357005, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 3.14387012286464, 'reg_lambda': 3.5786944629545054, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5139395282614464, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8552353449924772, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.500077545197049, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05961016562890632, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.8994217289802827, 'reg_lambda': 2.0585238865802378, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6220282066705893, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9874427872081837, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.5914547082453763, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.028963694924084273, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.666306110028411, 'reg_lambda': 4.593639431611545, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5335400848391941, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.799756721522443, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 3.0572607980300726, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.0728133995644329, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 3.2886181107518007, 'reg_lambda': 3.5591358467985152, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5723745499491157, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8418665209521705, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.7554013346272764, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.018230062668635166, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 3.3646695782757843, 'reg_lambda': 2.6008769165584384, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.516267503330369, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9145281894799755, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 3.7287906178329693, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.03869982660790042, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.7248641525527518, 'reg_lambda': 4.422430350802219, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5553794677369795, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.826089070881606, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 3.6866214594869744, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.03463995628632027, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.9684744983501712, 'reg_lambda': 4.478499068047224, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5933338775199068, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9866579545226626, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.12871664572618957, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.020463126181263853, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.038219863827645084, 'reg_lambda': 0.35937443597417074, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6230415202991992, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.7739995817750975, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.525921811825447, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.01014463741119205, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.6551185171621509, 'reg_lambda': 4.041812210910465, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6367497918514236, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8073614818967179, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.1203755004957525, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.03144402961661375, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.9074442952156971, 'reg_lambda': 4.845914645090691, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5161063561233991, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8728575467683044, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.0434706623491503, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.01059366042745763, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 3.3722592194511076, 'reg_lambda': 1.7156460012694619, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5460779862717555, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8970547398415736, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.0243863308676882, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.04704956937536414, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.592764118851966, 'reg_lambda': 1.5341537253767945, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6357656435389227, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6580803483949446, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.199570915595486, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.04847901017649369, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.7814666942162055, 'reg_lambda': 0.6082038843143595, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5710897190505022, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.5212904356699087, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 2.4693858007439173, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.07437095451441372, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.7904632644764297, 'reg_lambda': 3.951075451422539, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6000393293060796, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.5376919998402261, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 3.0651482276462065, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.014307932510069371, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.1315505987861452, 'reg_lambda': 3.6526461012969285, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6018969200229627, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9182929892965429, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.21318307815770043, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.023706464367797282, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.6224493586128343, 'reg_lambda': 2.343553528324043, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.576749176960753, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8414081894550707, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.5419114353085188, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.048230592792536796, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.1762980756875588, 'reg_lambda': 2.642175974591069, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6372073815976459, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# ...
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6341719368900656, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.2838259455965, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.0718472116331255, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.9440785011572681, 'reg_lambda': 1.2584742221348995, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5754808051902669, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.850084194970842, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.779766567675092, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.04586297560447049, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.12315504276447918, 'reg_lambda': 2.5005644295692275, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6279005066761547, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.817249743443147, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.989493248764177, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.012896141117366354, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 2.218095451444737, 'reg_lambda': 0.1262385522727788, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.618635454059674, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8840533266756667, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.4691263008919597, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.024536306198059462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.840346699924593, 'reg_lambda': 4.632644602724761, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5309096362033033, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.7531709924552165, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 3.547999011026474, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05087911686121665, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.3674954085992487, 'reg_lambda': 1.069789131295228, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6280292992778119, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9236476401730047, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.579307061318121, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05397941620668227, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.32558066312689776, 'reg_lambda': 0.5423752272345567, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5852776601216209, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.783333196964944, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.474770874908557, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.016376589837993557, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 2.8391069389787917, 'reg_lambda': 4.896939037126442, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5213875009610027, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9182461989076707, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.904462638230648, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.041663173086122024, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.8025843994079191, 'reg_lambda': 2.7682566020503967, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5717086283561896, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 2 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8363699765067971, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 4.5578178047563505, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.03551849788344525, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 3.319381345461589, 'reg_lambda': 4.886662625425126, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5775994329165453, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6067953622116619, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 3.4336810388142505, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.04802117494683363, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 0.19226768425020538, 'reg_lambda': 0.16500326550701938, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5639726991871041, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.5462263461124351, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 1.5260292198764036, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.04341452524937975, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 1, 'max_leaves': None, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 1, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': 1.1305791940031793, 'reg_lambda': 2.4302896678571804, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.5847809273329518, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3}
# num_round: 20, Accuracy: 0.956
# TEST: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 1 1 2 2 1 2 1 1 0 2 2 2 2 2 1 0 2 1 0 0 1 1
#  0 1 1 0 2 0 0 0]
# PRED: [2 1 0 0 1 1 2 1 2 1 0 1 2 0 0 0 1 2 1 1 2 1 1 0 2 2 2 2 2 1 0 2 1 2 0 1 1
#  2 1 1 0 2 0 0 0]
